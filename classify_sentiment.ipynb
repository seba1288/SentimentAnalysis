# %%
import pandas as pd
import string
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 3
#       1 import pandas as pd
#       2 import string
# ----> 3 from vadersentiment.vaderSentiment import SentimentIntensityAnalyzer
#
# ModuleNotFoundError: No module named 'vadersentiment'

# %% [markdown]
# ## Read opinions from CSV file

# %%
opinions = pd.read_csv('./Opinions/opinions_full2.csv', encoding='utf-8')
# Out:
# /var/folders/89/6rr92zhj2c7520dbhvqxdffm0000gn/T/ipykernel_65839/815880691.py:1: DtypeWarning: Columns (6,7,8,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   opinions = pd.read_csv('./Opinions/opinions_full2.csv', encoding='utf-8')

# %%
opinions = opinions[["opinion", "score","sentiment"]]

# %%
opinions.sentiment = opinions.sentiment.str.lower()

# %%
sa = SentimentIntensityAnalyzer()
opinions.vader = opinions.opinion.apply(lambda o: sa.polarity_scores(o))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sa = SentimentIntensityAnalyzer()
#       2 opinions.vader = opinions.opinion.apply(lambda o: sa.polarity_scores(o))
#
# NameError: name 'SentimentIntensityAnalyzer' is not defined
